# %%
from itertools import chain
from pathlib import Path

import matlab.engine

from skrt import Patient
from skrt.registration import get_default_pfiles_dir, Registration, set_elastix_dir

# Define paths to patient data.
# Each dataset consists of the CT image used in treatment planning,
# and the associated structure set.
# In each structure set, IMNs are outlined on the patient's left or right only.
# The side on which the IMNs are outlined is indicated in the name of the
# directory containing the patient directories.
data_dir = Path("~/data/casscade").expanduser()
paths = sorted(list(chain(data_dir.glob('casscade*/[!.]*'))))

# Set path to Elastix installation.
elastix_dir = Path('~/sw/elastix-5.0.1').expanduser()
set_elastix_dir(elastix_dir)

# Obtain path to default Elastix parameter files.
pfiles_dir = get_default_pfiles_dir()

# Indicate whether to print information for checking progress and data content.
verbose = True

# %%
# Load data.
patients = {"left": [], "right": []}
ids = []
for path in paths:
    if ids and path.name not in ids:
        continue
    # Determine side on which IMNs are outlined from path.
    side = path.parent.name.split("_")[1]
    patients[side].append(Patient(path, unsorted_dicom=True))
    if verbose:
        print(f"({side}) {patients[side][-1].id} - initialisation; "
              f"{patients[side][-1]._init_time:.2f} s; ")
# Out:
# (left) z0k0jwfmkl - initialisation; 0.55 s;
# (left) z0k0kwmghm - initialisation; 0.49 s;
# (left) z0k0lufhhn - initialisation; 0.43 s;
# (left) z0k0lzkfkp - initialisation; 0.58 s;
# (left) z0k0lzmggq - initialisation; 0.56 s;
# (left) z0k0mzjjij - initialisation; 0.57 s;
# (left) z0k0nrmkko - initialisation; 0.45 s;
# (left) z0k0nshmjp - initialisation; 0.48 s;
# (left) z0k0nsmjnl - initialisation; 0.53 s;
# (left) z0k0nvmgkq - initialisation; 0.52 s;
# (left) z0k0pxfejq - initialisation; 0.64 s;
# (left) z0k0q1ogkn - initialisation; 0.50 s;
# (left) z0k0qzkekh - initialisation; 0.44 s;
# (left) z0k1kwihfp - initialisation; 0.49 s;
# (left) z0k1luinem - initialisation; 0.57 s;
# (left) z0k1nxmgeo - initialisation; 0.40 s;
# (left) z0k1ozngil - initialisation; 0.51 s;
# (left) z0k2irkmnn - initialisation; 0.57 s;
# (left) z0k2rtkjkh - initialisation; 0.46 s;
# (left) z0k3jtihlp - initialisation; 0.72 s;
# (left) z0k3lxmiij - initialisation; 0.57 s;
# (left) z0k3nsmelj - initialisation; 0.70 s;
# (left) z0k3qrijjo - initialisation; 0.54 s;
# (left) z0k4izonnq - initialisation; 0.56 s;
# (left) z0k4k1ohgl - initialisation; 0.62 s;
# (left) z0k4ksgmgo - initialisation; 0.64 s;
# (left) z0k4nsgefj - initialisation; 0.56 s;
# (left) z0k4orgnhh - initialisation; 0.59 s;
# (left) z0k4owjimm - initialisation; 0.66 s;
# (left) z0k4oyifil - initialisation; 0.61 s;
# (left) z0k4oykeio - initialisation; 0.59 s;
# (left) z0k4p1olfj - initialisation; 0.64 s;
# (left) z0k4pxmkji - initialisation; 0.76 s;
# (left) z0k4q1hkhj - initialisation; 0.59 s;
# (left) z0k4rwinio - initialisation; 0.57 s;
# (right) z0k0lzffmq - initialisation; 0.53 s;
# (right) z0k0lznlgi - initialisation; 0.62 s;
# (right) z0k0mzlefq - initialisation; 0.69 s;
# (right) z0k0osggnk - initialisation; 0.63 s;
# (right) z0k0owjlli - initialisation; 0.59 s;
# (right) z0k0pskknq - initialisation; 0.61 s;
# (right) z0k1mrgnil - initialisation; 0.69 s;
# (right) z0k1nrnlnj - initialisation; 0.51 s;
# (right) z0k1nvjglm - initialisation; 0.59 s;
# (right) z0k1nvjmjm - initialisation; 0.77 s;
# (right) z0k1ovjlmp - initialisation; 0.56 s;
# (right) z0k1qslien - initialisation; 0.63 s;
# (right) z0k1qxhmeo - initialisation; 0.59 s;
# (right) z0k1rzfknp - initialisation; 0.53 s;
# (right) z0k1rzjjjk - initialisation; 0.66 s;
# (right) z0k3lxmiij - initialisation; 0.61 s;
# (right) z0k3m1kjgo - initialisation; 0.65 s;
# (right) z0k3myhigq - initialisation; 0.61 s;
# (right) z0k3nvojkp - initialisation; 0.68 s;
# (right) z0k3ovnegl - initialisation; 0.60 s;
# (right) z0k3owkffh - initialisation; 0.60 s;
# (right) z0k3oylnij - initialisation; 0.45 s;
# (right) z0k3pyjllq - initialisation; 0.37 s;
# (right) z0k4nslein - initialisation; 0.45 s;
# (right) z0k4nvhmki - initialisation; 0.46 s;
# (right) z0k4owmnlj - initialisation; 0.56 s;
# (right) z0k4pvkmnq - initialisation; 0.58 s;
# (right) z0k4rvhhfj - initialisation; 0.62 s;
# (right) z0k4rvnjnh - initialisation; 0.45 s;

# %%
# For each patient, check that number of images and number of structure sets
# are both equal to 1, then print names of all ROIs
# and names or OARs to be considered in auto-segmentation.
all_oar_names = set()
for side in patients:
    if verbose:
        print(f"\n{side}: {len(patients[side])}")
    for patient in patients[side]:
        images = patient.combined_objs("image_types")
        assert 1 == len(images)
        structure_sets = patient.combined_objs("structure_set_types")
        assert 1 == len(structure_sets)
        
        ss = structure_sets[0]
        roi_names = [roi_name for roi_name in sorted(ss.get_roi_names())]
        oar_names = [roi_name for roi_name in roi_names if True in
                     [oar_name in roi_name for oar_name in
                      ["hear", "Heart", "inm", "imn", "INM", "IMN"]]]
        if verbose:
            print(f"\n({side}) {patient.id} - study timestamp: {patient.studies[0].timestamp}")
            print(f"    {roi_names}")
            print(f"    {oar_names}")
        all_oar_names = all_oar_names.union(oar_names)   
        
all_oar_names = sorted(list(all_oar_names))
if verbose:
    print(f"\n{all_oar_names}")
        
"""
idx = 0
patient = patients[idx]
study = patient.studies[0]
ct = study.ct_images[0]
ss = study.ct_structure_sets[0]
ct.view(rois=ss)
""";
assert True == False
# Out:
# left: 35
#
# (left) z0k0jwfmkl - study timestamp: 20200901_145209
#     ['CTV INM', 'CTV intercept', 'CTV level 2', 'CTV level 3', 'CTV level 4', 'Heart', 'L_Lung', 'Oesophagus', 'PTVn_LN_Ax_L2_L', 'PTVn_LN_Ax_L3_L', 'PTVn_LN_Ax_L4_L', 'PTVn_LN_Combined', 'PTVn_LN_IMN_L', 'PTVn_LN_Intercept_L', 'PTVp_4000', 'R_Breast', 'R_Lung', 'Skin', 'Skin-PTVAndAx', 'ptv imn dvh', 'zzMLC Guide', 'zzVOIAxilla And Skin']
#     ['CTV INM', 'Heart', 'PTVn_LN_IMN_L', 'ptv imn dvh']
#
# (left) z0k0kwmghm - study timestamp: 20211116_190607
#     ['32Gy isodose', '36Gy isodose', '38Gy isodose', 'A', 'CTVn_IMN', 'CTVn_Level_1', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'CTVp_4000_DNU', 'Carotid Artery', 'Contra_Breast', 'Contra_Lung', 'Couch Top', 'FLASH', 'Heart', 'Heart_inField', 'HumeralHead_1cm', 'Humeralhead', 'Ipsi_Lung', 'LN_PTV_DVH', 'Oesophagus', 'PTV LN AX ONLY', 'PTV_Combined', 'PTV_WB_DVH', 'PTVn_LN_Ax_L1', 'PTVn_LN_Ax_L1_DVH', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L2_DVH', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L3_DVH', 'PTVn_LN_Ax_L4', 'PTVn_LN_Ax_L4_DVH', 'PTVn_LN_Combined', 'PTVn_LN_IMN', 'PTVn_LN_IMN_DVH', 'PTVp_4000', 'PTVp_4000_WT', 'Skin', 'Skin-PTVAndAx', 'SkinMinus0.5cm', 'SpinalCord', 'd50_TANGS', 'zz32spillage', 'zz33', 'zzArm', 'zzArm_BLOCK', 'zzRVR', 'zzRing_AllPTV']
#     ['CTVn_IMN', 'Heart', 'Heart_inField', 'PTVn_LN_IMN', 'PTVn_LN_IMN_DVH']
#
# (left) z0k0lufhhn - study timestamp: 20210415_124021
#     ['Heart', 'Oesophagus', 'PLAN BOLUS']
#     ['Heart']
#
# (left) z0k0lzkfkp - study timestamp: 20200701_123108
#     ['Axilla beam field', 'CTV INM', 'CTV level 1', 'CTV level 2', 'CTV level 3', 'CTV level 4', 'Heart', 'L_Breast', 'L_Lung', 'Lat beam', 'Lat beam field', 'Med beam field', 'PTVn_LN_Ax_L1_L', 'PTVn_LN_Ax_L2_L', 'PTVn_LN_Ax_L3_L', 'PTVn_LN_Ax_L4_L', 'PTVn_LN_Combined', 'PTVn_LN_IMN_L', 'PTVp_4000', 'R_Breast', 'R_Lung', 'Skin', 'Skin-PTVAndAx', 'axillaroi', 'axillaroi and Lt_Lung', 'axillia beam', 'beam1', 'beam1 and skin', 'beam1 and skin - Lt_Lung', 'box', 'chest wall', 'guide beam', 'humeral head', 'humeral head + 10mm', 'med2', 'ptv imn dvh', 'skin -5', 'subclav a', 'subclav v', 'tangentroi', 'tangentroi and Lt_Lung']
#     ['CTV INM', 'Heart', 'PTVn_LN_IMN_L', 'ptv imn dvh']
#
# (left) z0k0lzmggq - study timestamp: 20210831_094352
#     ['32', '36', '38', 'CTVn_IMN', 'CTVn_Level_1', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'Contra_Breast', 'Contra_Lung', 'Couch Top', 'FLASH', 'Heart', 'Heart_inField', 'HumeralHead_1cm', 'Humeralhead', 'Ipsi_Lung', 'LN_PTV_DVH', 'Oesophagus', 'PTV LN AX ONLY', 'PTV_Combined', 'PTV_WB_DVH', 'PTVn_LN_Ax_L1', 'PTVn_LN_Ax_L1_DVH', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L2_DVH', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L3_DVH', 'PTVn_LN_Ax_L4', 'PTVn_LN_Ax_L4_DVH', 'PTVn_LN_Combined', 'PTVn_LN_IMN', 'PTVn_LN_IMN_DVH', 'PTVp_4000', 'PTVp_4000_WT', 'Skin', 'Skin-PTVAndAx', 'SkinMinus0.5cm', 'SubclavianAxially Artery', 'SubclavianAxially Vein', 'd50_TANGS', 'spill', 'zz105', 'zzArm', 'zzArm_BLOCK', 'zzRVR', 'zzRing_AllPTV']
#     ['CTVn_IMN', 'Heart', 'Heart_inField', 'PTVn_LN_IMN', 'PTVn_LN_IMN_DVH']
#
# (left) z0k0mzjjij - study timestamp: 20211015_181848
#     ['CTVn_Level_1', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'Contra_Breast', 'Contra_Lung', 'D50', 'Heart', 'HumeralHead_1cm', 'Humeralhead', 'Ipsi_Lung', 'Oesophagus', 'PTVn_LN_Ax_L1', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L4', 'PTVn_LN_Combined', 'PTVp_4000', 'Skin', 'Skin-PTVAndAx', 'SkinMinus0.5cm', 'SubclavianAxially Artery', 'field guide']
#     ['Heart']
#
# (left) z0k0nrmkko - study timestamp: 20201123_162913
#     ['CTV INM', 'CTV level 3', 'CTV level 4', 'Heart', 'L_Lung', 'PTV IMN DVH', 'PTV IMN DVH (1)', 'PTVn_LN_Ax_L3_L', 'PTVn_LN_Ax_L4_L', 'PTVn_LN_Combined', 'PTVn_LN_IMN_L', 'PTVp_4000', 'R_Breast', 'R_Lung', 'Skin', 'Skin-PTVAndAx', 'zzMLC Guide', 'zzOesophagus avoid']
#     ['CTV INM', 'Heart', 'PTV IMN DVH', 'PTV IMN DVH (1)', 'PTVn_LN_IMN_L']
#
# (left) z0k0nshmjp - study timestamp: 20210831_160228
#     ['1', '32Gy isodose', '36Gy isodose', '38Gy isodose', 'A', 'B', 'C', 'CTVn_IMN', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'Carotid Artery', 'Contra_Breast', 'Contra_Lung', 'Couch Top', 'FLASH', 'Heart', 'Heart_inField', 'HumeralHead_1cm', 'Humeralhead', 'InternalJugular', 'Ipsi_Lung', 'LN_PTV_DVH', 'NEW D50 REPLAN', 'NEW PTV OPT', 'Oesophagus', 'PTV IMN DVH NEW PTV OPT', 'PTV IMN OPT', 'PTV LN AX ONLY', 'PTV_Combined', 'PTV_WB_DVH', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L2_DVH', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L3_DVH', 'PTVn_LN_Ax_L4', 'PTVn_LN_Ax_L4_DVH', 'PTVn_LN_Combined', 'PTVn_LN_IMN', 'PTVn_LN_IMN_DVH', 'PTVp_4000', 'PTVp_4000_WT', 'Skin', 'Skin-PTVAndAx', 'SkinMinus0.5cm', 'SubclavianAxially Artery', 'SubclavianAxially Vein', 'd50_TANGS', 'spill', 'zzArm', 'zzArm_BLOCK', 'zzRVR', 'zzRing_AllPTV']
#     ['CTVn_IMN', 'Heart', 'Heart_inField', 'PTV IMN DVH NEW PTV OPT', 'PTV IMN OPT', 'PTVn_LN_IMN', 'PTVn_LN_IMN_DVH']
#
# (left) z0k0nsmjnl - study timestamp: 20201215_112012
#     ['CTV INM', 'CTV level 2', 'CTV level 3', 'CTV level 4', 'Heart', 'L_Lung', 'PTV IMN DVH', 'PTVn_LN_Ax_L2_L', 'PTVn_LN_Ax_L3_L', 'PTVn_LN_Ax_L4_L', 'PTVn_LN_Combined', 'PTVn_LN_IMN_L', 'PTVp_4000', 'R_Breast', 'R_Lung', 'Skin', 'Skin-PTVAndAx', 'zzMLC Guide', 'zz_guide LN PTV']
#     ['CTV INM', 'Heart', 'PTV IMN DVH', 'PTVn_LN_IMN_L']
#
# (left) z0k0nvmgkq - study timestamp: 20220117_084736
#     ['32Gy isodose', '36Gy isodose', '38Gy isodose', 'CTVn_IMN', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'Carotid Artery', 'Contra_Breast', 'Contra_Lung', 'Couch Top', 'FLASH', 'Heart', 'HumeralHead_1cm', 'Humeralhead', 'InternalJugular', 'Ipsi_Lung', 'Oesophagus', 'PTV_Combined', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L4', 'PTVn_LN_Combined', 'PTVn_LN_IMN', 'PTVp_4000', 'Skin', 'Skin-PTVAndAx', 'SkinMinus0.5cm', 'SpinalCord', 'SubclavianAxially Artery', 'SubclavianAxially Vein', 'zz105', 'zz107', 'zz32spill', 'zz32spillageOPT', 'zz95', 'zzArm', 'zzArm_BLOCK', 'zzRVR', 'zzRing_AllPTV', 'zzspillage_105', 'zztopup']
#     ['CTVn_IMN', 'Heart', 'PTVn_LN_IMN']
#
# (left) z0k0pxfejq - study timestamp: 20210528_161252
#     ['32Gy isodose', '36Gy isodose', '38Gy isodose', '4th rib', 'CTVn_IMN', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'CTVp_4800', 'Carotid Artery', 'Couch Top', 'FLASH', 'Heart', 'HumeralHead_1cm', 'Humeralhead', 'InternalJugular', 'L_Lung', 'Oesophagus', 'Oesophagus dr', 'PTVCombined', 'PTVn_LN_Ax_L2_L', 'PTVn_LN_Ax_L3_L', 'PTVn_LN_Ax_L4_L', 'PTVn_LN_Combined', 'PTVn_LN_IMN_L', 'PTVp_4000', 'PTVp_4000-PTVp_4800_DVH', 'PTVp_4000-PTVp_4800_DVH+1cm', 'PTVp_4800', 'PTVp_4800_DVH', 'PTVp_4800_DVH+1cm', 'R_Breast', 'R_Lung', 'Skin', 'Skin-PTVAndAx', 'SkinMinus0.5cm', 'SubclavianAxially Artery', 'SubclavianAxially Vein', 'c', 'p', 'right breast', 'x', 'zzArmBlock', 'zzPTVp_4000-PTVp_4800+2cm', 'zzRVR', 'zzRing1', 'zzRing1TB', 'zzRing2', 'zzRing2TB', 'zzRing3TB', 'zzd50']
#     ['CTVn_IMN', 'Heart', 'PTVn_LN_IMN_L']
#
# (left) z0k0q1ogkn - study timestamp: 20220214_091057
#     ['32Gy isodose', '36Gy isodose', '38Gy isodose', 'CTVn_IMN', 'CTVn_Level_1', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'Contra_Breast', 'Contra_Lung', 'Couch Top', 'FLASH', 'Heart', 'HumeralHead_1cm', 'Humeralhead', 'Ipsi_Lung', 'Liver', 'Oesophagus', 'PTV_Combined', 'PTVn_LN_Ax_L1', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L4', 'PTVn_LN_Combined', 'PTVn_LN_IMN', 'PTVp_4000', 'Skin', 'Skin-PTVAndAx', 'SkinMinus0.5cm', 'SpinalCord', 'zz12spill', 'zz32spill', 'zz32spillOPT', 'zz38spill', 'zz38spill_OPT', 'zzArm', 'zzArm_BLOCK', 'zzRVR', 'zzRing_AllPTV']
#     ['CTVn_IMN', 'Heart', 'PTVn_LN_IMN']
#
# (left) z0k0qzkekh - study timestamp: 20210211_124033
#     ['4th interspace', 'D50', 'L_Lung', 'PTV IMN DVH', 'PTVn_LN_Ax_L2_L', 'PTVn_LN_Ax_L3_L', 'PTVn_LN_Ax_L4_L', 'PTVn_LN_Combined', 'PTVn_LN_IMN_L', 'PTVn_LN_Intercept_L', 'PTVp_4000', 'R_Breast', 'R_Lung', 'SCF D50', 'Skin', 'Skin-PTVAndAx', 'ctv imn', 'ctv level 3', 'ctv level 4', 'ctv upper interpect', 'ctv upper level 2', 'heart', 'oesophagus avoid', 'sca', 'zzGuide', 'zzLung in field2']
#     ['PTV IMN DVH', 'PTVn_LN_IMN_L', 'ctv imn', 'heart']
#
# (left) z0k1kwihfp - study timestamp: 20211007_172314
#     ['CTVn_IMN', 'CTVn_Level_1', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'Carotid Artery', 'Contra_Breast', 'Contra_Lung', 'D50', 'Heart', 'HumeralHead_1cm', 'Humeralhead', 'InternalJugular', 'Ipsi_Lung', 'Oesophagus', 'PTVn_LN_Ax_L1', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L4', 'PTVn_LN_Combined', 'PTVn_LN_IMN', 'PTVp_4000', 'Skin', 'Skin-PTVAndAx', 'SkinMinus0.5cm', 'SubclavianAxially Artery', 'SubclavianAxially Vein']
#     ['CTVn_IMN', 'Heart', 'PTVn_LN_IMN']
#
# (left) z0k1luinem - study timestamp: 20210621_113402
#     ['32Gy REPLAN', '36Gy REPLAN', '38Gy REPLAN', 'CTVn_IMN', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'Contra_Breast', 'Contra_Lung', 'Couch Top', 'FLASH replan', 'Heart', 'Heart_inField', 'HumeralHead_1cm', 'Humeralhead', 'Ipsi_Lung', 'LN_PTV_DVH', 'Oesophagus', 'PTV LN AX ONLY', 'PTV_Combined', 'PTV_WB_DVH', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L2_DVH', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L3_DVH', 'PTVn_LN_Ax_L4', 'PTVn_LN_Ax_L4_DVH', 'PTVn_LN_Combined', 'PTVn_LN_IMN', 'PTVn_LN_IMN_DVH', 'PTVp_4000', 'PTVp_4000_WT', 'Skin', 'Skin-PTVAndAx', 'SkinMinus0.5cm', 'SubclavianAxially Artery', 'SubclavianAxially Vein', 'd50_TANGS', 'zzArm', 'zzArm_BLOCK', 'zzRVR', 'zzRing_AllPTV']
#     ['CTVn_IMN', 'Heart', 'Heart_inField', 'PTVn_LN_IMN', 'PTVn_LN_IMN_DVH']
#
# (left) z0k1nxmgeo - study timestamp: 20210310_142706
#     ['4', 'CTV IMN', 'CTV interpectoral', 'CTV level 3', 'CTV level 4', 'CTV upper level 2', 'D50', 'Heart', 'L_Breast', 'L_Lung', 'PTVn_LN_Ax_L2_R', 'PTVn_LN_Ax_L3_R', 'PTVn_LN_Ax_L4_R', 'PTVn_LN_Combined', 'PTVn_LN_IMN_R', 'PTVn_LN_Interpect_R', 'PTVp_4000', 'R_Lung', 'Skin', 'Skin-PTVAndAx', 'oesophagus avoid', 'right humeral head', 'sca', 'zzguide', 'zzlung in field']
#     ['CTV IMN', 'Heart', 'PTVn_LN_IMN_R']
#
# (left) z0k1ozngil - study timestamp: 20220128_102906
#     ['32Gy isodose', '36Gy isodose', '38Gy isodose', 'CTVn_IMN', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'Contra_Breast', 'Contra_Lung', 'Couch Top', 'FLASH', 'Heart', 'HumeralHead_1cm', 'Humeralhead', 'Ipsi_Lung', 'Oesophagus', 'PTV_Combined', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L4', 'PTVn_LN_Combined', 'PTVn_LN_IMN', 'PTVp_4000', 'Skin', 'Skin-PTVAndAx', 'SkinMinus0.5cm', 'SpinalCord', 'SubclavianAxially Artery', 'SubclavianAxially Vein', 'zz32gy', 'zz32gy spill', 'zz38', 'zzArm', 'zzArm_BLOCK', 'zzRVR', 'zzRing_AllPTV', 'zzavoid']
#     ['CTVn_IMN', 'Heart', 'PTVn_LN_IMN']
#
# (left) z0k2irkmnn - study timestamp: 20210105_092525
#     ['CTV IMN', 'CTV LN', 'Heart', 'L_Lung', 'PTV IMN DVH', 'PTVn_LN_Combined', 'PTVp_4000', 'R_Breast', 'R_Lung', 'Skin', 'Skin-PTVAndAx', 'lleft chest wall', 'zz25', 'zzFG', 'zzol']
#     ['CTV IMN', 'Heart', 'PTV IMN DVH']
#
# (left) z0k2rtkjkh - study timestamp: 20210429_142624
#     ['Contra_Lung', 'Couch Top', 'Heart', 'Heart_inField', 'Ipsi_Lung', 'LN_PTV_DVH', 'Oesophagus', 'PTV LN AX ONLY', 'PTV_WB_DVH', 'PTVn_LN_Ax_L3_DVH', 'PTVn_LN_Ax_L4_DVH', 'PTVn_LN_IMN_DVH', 'PTVp_4000_WT', 'Planning Bolus', 'd50_TANGS']
#     ['Heart', 'Heart_inField', 'PTVn_LN_IMN_DVH']
#
# (left) z0k3jtihlp - study timestamp: 20220216_113338
#     ['32Gy isodose', '36Gy isodose', '38Gy isodose', 'CTVn_IMN', 'CTVn_Level_1', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'CTVp_4800', 'Carotid Artery', 'Contra_Breast', 'Contra_Lung', 'Couch Top', 'FLASH', 'Heart', 'HumeralHead_1cm', 'Humeralhead', 'InternalJugular', 'Ipsi_Lung', 'Oesophagus', 'PTV_Combined', 'PTVn_LN_Ax_L1', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L4', 'PTVn_LN_Combined', 'PTVn_LN_IMN', 'PTVp_4000', 'PTVp_4000-PTVp_4800_DVH', 'PTVp_4000-PTVp_4800_DVH+1cm', 'PTVp_4800', 'PTVp_4800_DVH', 'PTVp_4800_DVH+1cm', 'Skin', 'Skin-PTVAndAx', 'SkinMinus0.5cm', 'SpinalCord', 'SubclavianAxially Artery', 'SubclavianAxially Vein', 'zz32', 'zz32Gy', 'zz32OPT', 'zz32OPT2', 'zz38OPT', 'zz38cov', 'zz38covOPT', 'zz38spill', 'zz43', 'zz43OPT', 'zz43gy', 'zz44', 'zzArm', 'zzArm_BLOCK', 'zzRVR', 'zzRing1_SIB', 'zzRing2_SIB', 'zzRing_AllPTV', 'zzcov40', 'zzhotspots', 'zznew38', 'zznew38OPTspill', 'zznewcov38oPT']
#     ['CTVn_IMN', 'Heart', 'PTVn_LN_IMN']
#
# (left) z0k3lxmiij - study timestamp: 20210615_123553
#     ['32Gy', '36Gy', '38 Gy', 'CTVn_IMN', 'CTVn_Level_1', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'CTVp_4800', 'Contra_Breast', 'Contra_Lung', 'Couch Top', 'FLASH', 'Heart', 'Ipsi_Lung', 'Lungs', 'PTV_Combined', 'PTVn_LN_Ax_L1', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L4', 'PTVn_LN_Combined', 'PTVn_LN_IMN', 'PTVp_4000', 'PTVp_4000-PTVp_4800_DVH', 'PTVp_4000-PTVp_4800_DVH+1cm', 'PTVp_4800', 'PTVp_4800_DVH', 'PTVp_4800_DVH+1cm', 'Skin', 'Skin-PTVAndAx', 'spill', 'zzArm', 'zzArm_BLOCK', 'zzPlanning Bolus Full VMAT', 'zzRVR', 'zzRing1_SIB', 'zzRing2_SIB', 'zzRing_AllPTV']
#     ['CTVn_IMN', 'Heart', 'PTVn_LN_IMN']
#
# (left) z0k3nsmelj - study timestamp: 20210602_151619
#     ['32Gy', '36Gy', '38Gy', 'CTVn_IMN', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'Contra_Breast', 'Contra_Lung', 'Couch Top', 'FLASH', 'Heart', 'Heart_inField', 'HumeralHead_1cm', 'Humeralhead', 'InternalJugular', 'Ipsi_Lung', 'LN_PTV_DVH', 'L_Lung', 'Oesophagus', 'PTV_Combined', 'PTV_WB_DVH', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L2_DVH', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L3_DVH', 'PTVn_LN_Ax_L4', 'PTVn_LN_Ax_L4_DVH', 'PTVn_LN_Combined', 'PTVn_LN_IMN', 'PTVn_LN_IMN_DVH', 'PTVp_4000', 'PTVp_4000_DVH', 'PTVp_4000_WT', 'R_Lung', 'Rt Port', 'Skin', 'Skin-PTVAndAx', 'Skin1', 'Skin2', 'Skin3', 'SkinMinus0.5cm', 'SpinalCord', 'SubclavianAxially Artery', 'd50_TANGS', 'spill', 'v', 'zz32avoid', 'zz42', 'zzArm', 'zzArm_BLOCK', 'zzRVR', 'zzRing_AllPTV']
#     ['CTVn_IMN', 'Heart', 'Heart_inField', 'PTVn_LN_IMN', 'PTVn_LN_IMN_DVH']
#
# (left) z0k3qrijjo - study timestamp: 20210422_100407
#     ['32Gy', '36Gy', '38Gy', 'CTVn_IMN', 'CTVn_Interpect', 'CTVn_Level_1', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'Couch Top', 'FLASH', 'Heart', 'L_Breast', 'L_Lung', 'PTV_Combined', 'PTVn_LN_Ax_L1_R', 'PTVn_LN_Ax_L2_R', 'PTVn_LN_Ax_L3_R', 'PTVn_LN_Ax_L4_R', 'PTVn_LN_Combined', 'PTVn_LN_IMN_R', 'PTVn_LN_Interpect_R', 'PTVp_4000', 'R_Lung', 'Skin', 'Skin-PTVAndAx', 'zz1', 'zzblock', 'zzr1', 'zzr2', 'zzr3']
#     ['CTVn_IMN', 'Heart', 'PTVn_LN_IMN_R']
#
# (left) z0k4izonnq - study timestamp: 20210122_153728
#     ['40', '50', 'CTV IMN', 'CTV level 2', 'Heart1', 'IMN', 'IMN PTV DVH', 'IMN ptv', 'LN', 'LN ptv', 'L_Lung', 'Left chest wall', 'Lung (Left)', 'PTVn_LN_Combined', 'PTVn_LN_IMN_L', 'PTVp_4000', 'R_Breast', 'R_Lung', 'SCF D50', 'Skin', 'Skin-PTVAndAx', 'WB D50', 'guide', 'heart']
#     ['CTV IMN', 'Heart1', 'IMN', 'IMN PTV DVH', 'IMN ptv', 'PTVn_LN_IMN_L', 'heart']
#
# (left) z0k4k1ohgl - study timestamp: 20211014_084425
#     ['32Gy isodose', '36Gy isodose', '38Gy isodose', 'CTVn_IMN', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'CTVp_4800', 'Contra_Breast', 'Contra_Lung', 'Couch Top', 'FLASH', 'Heart', 'HumeralHead_1cm', 'Humeralhead', 'Ipsi_Lung', 'Oesophagus', 'PTV_Combined', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L4', 'PTVn_LN_Combined', 'PTVn_LN_IMN', 'PTVp_4000', 'PTVp_4000-PTVp_4800_DVH', 'PTVp_4000-PTVp_4800_DVH+1cm', 'PTVp_4800', 'PTVp_4800_DVH', 'PTVp_4800_DVH+1cm', 'Skin', 'Skin-PTVAndAx', 'SkinMinus0.5cm', 'cover', 'reduce', 'spill', 'zzArm', 'zzArm_BLOCK', 'zzPlanning Bolus Full VMAT', 'zzRVR', 'zzRing1_SIB', 'zzRing2_SIB', 'zzRing_AllPTV']
#     ['CTVn_IMN', 'Heart', 'PTVn_LN_IMN']
#
# (left) z0k4ksgmgo - study timestamp: 20201228_121206
#     ['CTV IMN', 'CTV level 2', 'CTV level 3', 'CTV level 4', 'Heart', 'L_Lung', 'PTVn_LN_Ax_L2_L', 'PTVn_LN_Ax_L3_L', 'PTVn_LN_Ax_L4_L', 'PTVn_LN_Combined', 'PTVn_LN_IMN_L', 'PTVp_4000', 'R_Breast', 'R_Lung', 'Skin', 'Skin-PTVAndAx', 'ptv imn dvh']
#     ['CTV IMN', 'Heart', 'PTVn_LN_IMN_L', 'ptv imn dvh']
#
# (left) z0k4nsgefj - study timestamp: 20201231_111809
#     ['3mmRing', '5mmRing', 'CTV IMN', 'CTV level 1', 'CTV level 2', 'CTV level 3', 'CTV level 4', 'CTVp_4800', 'Heart', 'L_Lung', 'PTVn_LN_Ax_L1_L', 'PTVn_LN_Ax_L2_L', 'PTVn_LN_Ax_L3_L', 'PTVn_LN_Ax_L4_L', 'PTVn_LN_Combined', 'PTVn_LN_IMN_L', 'PTVp_4000', 'PTVp_4000-PTVp_4800_DVH', 'PTVp_4000-PTVp_4800_DVH+1cm', 'PTVp_4800', 'PTVp_4800_DVH', 'PTVp_4800_DVH+1cm', 'Planning bolus', 'R_Breast', 'R_Lung', 'Skin', 'Skin-PTV', 'ptv imn dvh']
#     ['CTV IMN', 'Heart', 'PTVn_LN_IMN_L', 'ptv imn dvh']
#
# (left) z0k4orgnhh - study timestamp: 20210913_114639
#     ['32Gy isodose', '36Gy isodose', '38Gy isodose', 'CTVn_IMN', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'CTVp_4800', 'Contra_Breast', 'Contra_Lung', 'Couch Top', 'FLASH', 'Heart', 'Ipsi_Lung', 'OUTER RING', 'PTV_Combined', 'PTV_IMN-PTV48+1CM', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L4', 'PTVn_LN_Combined', 'PTVn_LN_IMN', 'PTVn_LN_IMN-PTVp_4800', 'PTVp_4000', 'PTVp_4000-PTVp_4800_DVH', 'PTVp_4000-PTVp_4800_DVH+1cm', 'PTVp_4800', 'PTVp_4800_DVH', 'PTVp_4800_DVH+1cm', 'RING 40', 'RING1 48', 'RVR', 'Skin', 'Skin-PTVAndAx', 'SkinMinus0.5cm', 'sternal met', 'zzArm', 'zzArm_BLOCK']
#     ['CTVn_IMN', 'Heart', 'PTV_IMN-PTV48+1CM', 'PTVn_LN_IMN', 'PTVn_LN_IMN-PTVp_4800']
#
# (left) z0k4owjimm - study timestamp: 20210205_161833
#     ['428', 'CTV INM', 'CTV level 3', 'CTV level 4', 'External', 'Heart', 'L_Breast', 'L_Lung', 'Lung (Left)', 'Lung (Right)', 'PTV IMN DVH', 'PTV Nodes combined', 'PTVn_LN_Ax_L3_L', 'PTVn_LN_Ax_L4_L', 'PTVn_LN_Combined', 'PTVn_LN_IMN_L', 'PTVp_4000', 'R_Breast', 'R_Lung', 'Skin', 'Skin-PTVAndAx', 'temp1', 'zz', 'zzOL', 'zzPTV NODES+5mm', 'zzfs']
#     ['CTV INM', 'Heart', 'PTV IMN DVH', 'PTVn_LN_IMN_L']
#
# (left) z0k4oyifil - study timestamp: 20210818_110252
#     ['32Gy isodose', '36Gy isodose', '38Gy isodose', 'CTVn_IMN', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'Carotid Artery', 'Contra_Breast', 'Contra_Lung', 'Couch Top', 'FLASH', 'Heart', 'Heart_inField', 'HumeralHead_1cm', 'Humeralhead', 'Ipsi_Lung', 'LN_PTV_DVH', 'Oesophagus', 'PTV LN AX ONLY', 'PTV_Combined', 'PTV_WB_DVH', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L2_DVH', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L3_DVH', 'PTVn_LN_Ax_L4', 'PTVn_LN_Ax_L4_DVH', 'PTVn_LN_Combined', 'PTVn_LN_IMN', 'PTVn_LN_IMN_DVH', 'PTVp_4000', 'PTVp_4000_WT', 'Skin', 'Skin-PTVAndAx', 'SkinMinus0.5cm', 'SubclavianAxially Artery', 'd50_TANGS', 'zzArm', 'zzArm_BLOCK', 'zzRVR', 'zzRing_AllPTV']
#     ['CTVn_IMN', 'Heart', 'Heart_inField', 'PTVn_LN_IMN', 'PTVn_LN_IMN_DVH']
#
# (left) z0k4oykeio - study timestamp: 20210329_134929
#     ['Couch Top', 'Heart', 'Oesophagus', 'Real Bolus 5mm', 'zzREAL AND PLAN BOLUS']
#     ['Heart']
#
# (left) z0k4p1olfj - study timestamp: 20211210_153824
#     ['32Gy isodose', '36Gy isodose', '38Gy isodose', '4th rib', 'CTVn_IMN', 'CTVn_Interpect', 'CTVn_Level_2', 'CTVn_Level_3', 'CTVn_Level_4', 'CTVp_4000', 'Carotid Artery', 'Contra_Breast', 'Contra_Lung', 'Couch Top', 'FLASH', 'Heart', 'Heart_inField', 'HumeralHead_1cm', 'Humeralhead', 'InternalJugular', 'Ipsi_Lung', 'LN_PTV_DVH', 'Lungs', 'Oesophagus', 'PTV LN AX ONLY', 'PTV_Combined', 'PTV_WB_DVH', 'PTVn_LN_Ax_L2', 'PTVn_LN_Ax_L2_DVH', 'PTVn_LN_Ax_L3', 'PTVn_LN_Ax_L3_DVH', 'PTVn_LN_Ax_L4', 'PTVn_LN_Ax_L4_DVH', 'PTVn_LN_Combined', 'PTVn_LN_IMN', 'PTVn_LN_IMN_DVH', 'PTVn_LN_Interpect', 'PTVn_LN_Interpect_DVH', 'PTVp_4000', 'PTVp_4000_WT', 'Skin', 'Skin-PTVAndAx', 'SkinMinus0.5cm', 'SubclavianAxially Artery', 'SubclavianAxially Vein', 'd50_TANGS', 'hot', 'zzArm', 'zzArm_BLOCK', 'zzRVR', 'zzRing_AllPTV']
#     ['CTVn_IMN', 'Heart', 'Heart_inField', 'PTVn_LN_IMN', 'PTVn_LN_IMN_DVH']
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [3], in <cell line: 5>()
#      10 assert 1 == len(images)
#      11 structure_sets = patient.combined_objs("structure_set_types")
# ---> 12 assert 1 == len(structure_sets)
#      14 ss = structure_sets[0]
#      15 roi_names = [roi_name for roi_name in sorted(ss.get_roi_names())]
#
# AssertionError:

# %%
# For selected patient, create registration with relapse scan as fixed image
idx = 0
p = patients[idx]

# Crop relapse scan to include structure-set ROIs plus margin.
ct_relapse = p.get_ct_relapse().clone()
ct_relapse.crop_to_roi(p.get_ss_relapse() + p.get_ss_recurrence(), buffer=100)

# Crop planning scan to size of cropped relapse scan.
ct_plan = p.get_ct_plan().clone()
ct_plan.crop_to_image(ct_relapse, alignment="spinal_canal")

# Define registration strategy.
reg = Registration(
    Path("results/relapse_fixed") / p.id,
    fixed=ct_relapse,
    moving=ct_plan,
    fixed_mask=None,
    initial_alignment = None,
    pfiles={
        #"translation": pfiles_dir / "MI_Translation.txt",
        "rigid": pfiles_dir / "MI_Rigid.txt",
        "affine": pfiles_dir / "MI_Affine.txt",
        #"bspline": pfiles_dir / "MI_BSpline30.txt"
    },
    overwrite=True,
    capture_output=True
)

# %%
# Perform registration.
reg.register()

# %%
# Show results at each step of registration.
for step in reg.steps:
    print(step)
    reg.view_result(step)

# %%
# Push ROI contours from relapse frame to planning frame.
ss_relapse_transformed = reg.transform(p.get_ss_relapse(), transform_points=True)
ss_recurrence_transformed = reg.transform(p.get_ss_recurrence(), transform_points=True)
ss_recurrence_transformed["recurrence"].name = "Transformed_recurrence"

# %%
# Show relapse scan with ROI contours outlined on scan,
# and ROI contours pushed from planning scan.
reg.moving_image.view(rois=ss_relapse_transformed + p.get_ss_plan())

# %%
# Show recurrence mapped to planning scan and on relapse scan.
ct_plan.view(images=ct_relapse, rois=[ss_recurrence_transformed, p.get_ss_recurrence()])
